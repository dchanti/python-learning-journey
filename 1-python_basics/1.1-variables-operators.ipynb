# %% [markdown]
# ### Variables

# %%
age=32 ## int 
height=6.1 ##FLOAT 
name="kailash" ##string 
is_student=True ## bool

# %% [markdown]
# ### Printing

# %%
print("my name is",name,"my age is",age,"my height is",height)
# Out:
# my name is kailash my age is 32 my height is 6.1

# %% [markdown]
# ### Type Casting

# %%
age="20"
print(type(age));
# Out:
# <class 'str'>

# %%
new_age=int(age)
print(new_age)
# Out:
# 20

# %%
print(type(new_age))
# Out:
# <class 'int'>

# %%
## like this can be converted string to int int to string all integers can be \
##converted into string but not all string scanbe converted into int only 
# number strings can be converted into string

# %%
### in python we can change the data type of a
#  variable in othe rlanguages like in c++ if 
# int a is declared only int only gets stored

# %%
##example
a=20
print(type(a))
a="20"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### INput taking
# in python any input we take it gets like an string
# so every time we should type caste them

# %%
id=input("enter ur id ");
print(type(id))
# Out:
# <class 'str'>

# %%
##so we can convert directly while taking input or else separately
roll_no=int(input("ener ur roll no"))
print(roll_no, type(roll_no))
##or
rollid=input("enter ur roll id")
roll=int(rollid);
print(rollid,type(roll))
# Out:
# 23 <class 'int'>
# 25 <class 'int'>

# %% [markdown]
# ### logical and or operators

# %%
a=25
b=36
if (a>20) and (b>30):
    print("ohooo")
else: print("kyaaa")
# Out:
# ohooo

# %%
a=25
b=36
if (a>20) or (b<30):
    print("ohooo")
else: print("kyaaa")
# Out:
# ohooo
