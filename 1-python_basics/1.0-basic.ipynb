# %%
###comment

# %%
## single line comments

# %%
## print () used to print the stuff
print(1+2)
# Out:
# 3

# %% [markdown]
# ### Intendation

# %%
if 1>2:
    print(1)
else:
    print(0)
# Out:
# 0

# %%
##Use a backslash (\) to continue a statement to the next line
sum=1+2+3+4+5+6+\
7+8+9
print(sum)
# Out:
# 45

# %%
age=27
type(age)
# Out:
# int

# %%
age="twentty"
type(age)
# Out:
# str

# %%
## no need to specify data type it automatically takes 
name='chanti'
type(name)
# Out:
# str
